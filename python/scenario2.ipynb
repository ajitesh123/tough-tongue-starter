# %%
import requests
import json
import getpass

# %%
def get_auth_token():
    url = "https://api.toughtongueai.com/api/public/scenarios"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer wFBO6IHJZFQLqaZrc1KmxHg3w1se-xIyVLqtzx0zBz8"
    }

    response = requests.get(url, headers=headers)
    data = response.json()
    print(data)

# %%
def create_scenario(token, scenario_data):
    url = "https://api.toughtongueai.com/api/public/scenarios"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {token}"
    }
    try:
        response = requests.post(url, headers=headers, json=scenario_data)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"Error creating scenario: {e}")
        return None

# %%
freelancer_scenario = {
    "name": "Freelancer Rate Negotiation",
    "description": "Practice negotiating project rates with a potential client who has a limited budget.",
    "context": {
        "role": "Freelancer",
        "opponent": "Small Business Owner",
        "setting": "Video call to discuss a 3-month web development project",
        "objectives": [
            "Secure a fair hourly rate",
            "Highlight your unique skills",
            "Address budget constraints creatively"
        ],
        "tone": "Professional but friendly",
        "constraints": {
            "client_budget": "$5000",
            "project_duration": "3 months",
            "min_acceptable_rate": "$40/hour"
        }
    },
    "ai_instructions": (
        "Act as a small business owner who wants quality work but has a limited budget. Be budget-conscious and push back on high rates. "
        "Show willingness to negotiate but aim to stay under $5000."
    ),
    "is_public": False,
    "tags": ["negotiation", "freelancing", "business"]
}

# %%
conflict_scenario = {
    "name": "Resolve Team Conflict Over Tech Stack",
    "description": "Practice mediating a disagreement between developers on choosing a tech stack.",
    "context": {
        "role": "Tech Lead",
        "opponent": "Two Senior Developers",
        "setting": "Team meeting to finalize tech stack for a new project",
        "objectives": [
            "Reach a consensus on tech stack",
            "Ensure both developers feel heard",
            "Keep the project timeline intact"
        ],
        "tone": "Collaborative and decisive",
        "constraints": {
            "project_deadline": "6 months",
            "options": ["React vs. Vue", "Node.js vs. Django"],
            "team_size": 5
        }
    },
    "ai_instructions": (
        "Play the role of two developers. One strongly favors React and Node.js, the other advocates for Vue and Django. "
        "Both are experienced and passionate. Express clear arguments, but be open to compromise if the Tech Lead shows leadership."
    ),
    "is_public": True,
    "tags": ["leadership", "conflict resolution", "technical"]
}

# %%
vocab_builder_payload = {
    "name": "vocabulary_builder_business_context",
    "title": "Improve Your Business Vocabulary",
    "description": "Practice using advanced business vocabulary in realistic workplace conversations.",
    "context": (
        "You are preparing for an important job interview at a consulting firm. "
        "Your goal is to use more professional and impactful language while discussing business strategy, performance metrics, and collaboration. "
        "You want to sound polished and confident while avoiding overused or vague terms. The setting is a mock interview with a senior partner."
    ),
    "role": "Job Candidate",
    "ai_instructions": (
        "Play the role of a senior partner at a consulting firm. Ask detailed questions about the candidate's strategic thinking, past team experience, and decision-making process. "
        "Provide constructive feedback when the candidate uses weak vocabulary and suggest more precise or powerful alternatives."
    ),
    "visibility": "private",
    "tags": ["vocabulary", "interview prep", "professional communication"]
}

# %%
def main():
    
    token = "LiMM9Wj2hcz9WHmMfHE7Qv5Kg8U0vrxJUZ1QM8_841o"

    # Create freelancer scenario
    # print("\nCreating Freelancer Rate Negotiation scenario...")
    # freelancer_result = create_scenario(token, freelancer_scenario)
    # if freelancer_result:
    #     print("Success! Scenario created:")
    #     print(json.dumps(freelancer_result, indent=2))

    # Create conflict resolution scenario
    # print("\nCreating Team Conflict Resolution scenario...")
    # conflict_result = create_scenario(token, conflict_scenario)
    # if conflict_result:
    #     print("Success! Scenario created:")
    #     print(json.dumps(conflict_result, indent=2))

    print("\nCreating Freelancer Rate Negotiation scenario...")
    vocab_result = create_scenario(token, vocab_builder_payload)
    if vocab_result:
        print("Success! Scenario created:")
        print(json.dumps(vocab_result, indent=2))

if __name__ == "__main__":
    main()
